# %%
# %load_ext autoreload
# %autoreload 2

# %%
from get_binding_potential_energy import get_binding_potential_energy

# %%
pp = get_binding_potential_energy('1brs_p.pdb')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9/9 [02:21<00:00, 15.67s/it]

# %%
pp
# Out:
# Quantity(value=-697.15393, unit=kilocalorie/mole)
